# %% [markdown]
# **CODEAZA PYTHON ASSIGNMENT 04**
#
# **OOP Principles in Python**
#
# ***Ojbectives***
#
#
# 1.  Polymorphism - Simply means having multiple forms
# 2.  Encapsulation - Code and Info is hide in classes and users don’t have access
# 3.  Inheritance - Inherit Parent Classes Behaviour
# 4.  Data Abstraction - Hide the complexity and provide only relevant information

# %% [markdown]
# **Polymorphism in Python**
#
# The word polymorphism means having many forms. In programming, polymorphism means having the same function name being used for different types of classes. The funciton defined in base class can be used in child classes but with different number of arguments.

# %%
class OOPinPython:
  
    def display_info(self):
        print("-------OOP IN PYTHON-------")
        print("Polymorphism")
        print("Encapsulation")
        print("Imheritance")
        print("Data Abstraction")
        print("---------------")


class Polymorphism():
    def display_info(self):
        print("Polymorphism: polymorphism means having many forms.")
        print("---------------")


class Encapsulation():
    def display_info(self):
        print("Encapsulation in Python is used to hide the sensitive data and prevent being accessed from outside class")
        print("---------------")


class Inheritance():
    def display_info(self):
        
        print("Inheritance allows us to define a class that inherits all the methods and properties from another class")
        print("---------------")

OOPinPython_obj = OOPinPython()
OOPinPython_obj.display_info()

polymorphism_obj = Polymorphism()
polymorphism_obj.display_info()

encapsulation_obj = Encapsulation()
encapsulation_obj.display_info()

inheritance_obj = Inheritance()
inheritance_obj.display_info()
# Out:
# -------OOP IN PYTHON-------
# Polymorphism
# Encapsulation
# Imheritance
# Data Abstraction
# ---------------
# Polymorphism: polymorphism means having many forms.
# ---------------
# Encapsulation in Python is used to hide the sensitive data and prevent being accessed from outside class
# ---------------
# Inheritance allows us to define a class that inherits all the methods and properties from another class
# ---------------

# %% [markdown]
# **ENCAPSULATION in Python**
#
# Encapsulation is fundamental principles of object-oriented programming in python that focuses on bundling data and methods together within a class, and controlling the access to that data from outside the class.

# %%
class OOPinPython:
    def __init__(self, concept, difficulty):
    # Public member variable
        self.concept = concept
    # Private member variable
        self.__difficulty = difficulty
    # Public method
    def get_concept(self):
        return self.concept
    #Private method
    def __get_difficulty(self):
        return self.__difficulty

    def display_info(self):
        print(f"Concept: {self.concept}")
        print(f"Difficulty: {self.__difficulty}")
        print("---------------")




OOPinPython_obj2 = OOPinPython("Encapsulation","Intermediate")
OOPinPython_obj2.display_info()

try:
    print(OOPinPython_obj2.concept)  # Attempting to access public member outside the class
except AttributeError:
    print("\nError: Private method cannot be accessed outside the class!!")

try:
    print(OOPinPython_obj2.get_concept())  # Attempting to access public method outside the class
except AttributeError:
    print("\nError: Private method cannot be accessed outside the class!!")

try:
    print(OOPinPython_obj2.__difficulty)  # Attempting to access private member outside the class
except AttributeError:
    print("\nError: Private member cannot be accessed outside the class!!")


try:
    print(OOPinPython.__get_difficulty)  # Attempting to access private member outside the class
except AttributeError:
    print("\nError: Private method cannot be accessed outside the class!!")
# Out:
# Concept: Encapsulation
# Difficulty: Intermediate
# ---------------
# Encapsulation
# Encapsulation
#
# Error: Private member cannot be accessed outside the class!!
#
# Error: Private method cannot be accessed outside the class!!

# %% [markdown]
# **INHERITANCE in Python**
#
# Inheritance allows us to define a class that inherits all the methods and properties from another class.
#
# Parent class is the class being inherited from, also called base class.
#
# Child class is the class that inherits from another class, also called derived class.

# %%
class OOPConcept:
    def __init__(self, concept, difficulty):
        self._concept = concept
        self._difficulty = difficulty

    def display_info(self):
        print(f"Concept: {self._concept}")
        print(f"Difficulty: {self._difficulty}")
        print("---------------")


class Polymorphism(OOPConcept):
    def __init__(self, concept, difficulty, usage):
        super().__init__(concept, difficulty)
        self._usage = usage

    def display_info(self):
        super().display_info()
        print(f"Usage of Polymorphism in Python: {self._usage}")
        print("---------------")


class Encapsulation(OOPConcept):
    def __init__(self, concept, difficulty, importance):
        super().__init__(concept, difficulty)
        self._importance = importance

    def display_info(self):
        super().display_info()
        print(f"Importance of Encapsulation in Python: {self._importance}")
        print("---------------")


class Inheritance(OOPConcept):
    def __init__(self, concept, difficulty, advantages):
        super().__init__(concept, difficulty)
        self._advantages = advantages

    def display_info(self):
        super().display_info()
        print(f"Advantages of Inheritance in Python: {self._advantages}")
        print("---------------")

OOPConcept_obj = OOPConcept("OOP CONCEPTS", "Beginner")
OOPConcept_obj.display_info()

polymorphism = Polymorphism("Polymorphism", "Intermediate", "Can have many forms")
polymorphism.display_info()

encapsulation = Encapsulation("Encapsulation", "Beginner", "Provides data protection")
encapsulation.display_info()

inheritance = Inheritance("Inheritance", "Advanced", "Code reusability and extensibility")
inheritance.display_info()
# Out:
# Concept: OOP CONCEPTS
# Difficulty: Beginner
# ---------------
# Concept: Polymorphism
# Difficulty: Intermediate
# ---------------
# Usage of Polymorphism in Python: Can have many forms
# ---------------
# Concept: Encapsulation
# Difficulty: Beginner
# ---------------
# Importance of Encapsulation in Python: Provides data protection
# ---------------
# Concept: Inheritance
# Difficulty: Advanced
# ---------------
# Advantages of Inheritance in Python: Code reusability and extensibility
# ---------------

# %% [markdown]
# **DATA ABSTRACTION in Python**
#
# Data Abstraction in python is defined as a process of handling complexity by hiding unnecessary information from the user. An abstract method is a method that is declared, but does not contain implementation. An abstract method in a base class identifies the functionality that should be implemented by all its subclasses.

# %%
from abc import ABC, abstractmethod

class OOPConcept(ABC):
    def __init__(self, concept, difficulty):
        self._concept = concept
        self._difficulty = difficulty

    @abstractmethod
    def display_info(self):
        pass


class Polymorphism(OOPConcept):
    def __init__(self, concept, difficulty, usage):
        super().__init__(concept, difficulty)
        self._usage = usage

    def display_info(self):
        print(f"Concept: {self._concept}")
        print(f"Difficulty: {self._difficulty}")
        print(f"Usage of Polymorphism in Python: {self._usage}")
        print("---------------")


class Encapsulation(OOPConcept):
    def __init__(self, concept, difficulty, importance):
        super().__init__(concept, difficulty)
        self._importance = importance

    def display_info(self):
        print(f"Concept: {self._concept}")
        print(f"Difficulty: {self._difficulty}")
        print(f"Importance of Encapsulation in Python: {self._importance}")
        print("---------------")


class Inheritance(OOPConcept):
    def __init__(self, concept, difficulty, advantages):
        super().__init__(concept, difficulty)
        self._advantages = advantages

    def display_info(self):
        print(f"Concept: {self._concept}")
        print(f"Difficulty: {self._difficulty}")
        print(f"Advantages of Inheritance in Python: {self._advantages}")
        print("---------------")


polymorphism = Polymorphism("Polymorphism", "Intermediate", "Can have many forms")
polymorphism.display_info()

encapsulation = Encapsulation("Encapsulation", "Beginner", "Provides data protection")
encapsulation.display_info()

inheritance = Inheritance("Inheritance", "Advanced", "Code reusability and extensibility")
inheritance.display_info()
# Out:
# Concept: Polymorphism
# Difficulty: Intermediate
# Usage of Polymorphism in Python: Can have many forms
# ---------------
# Concept: Encapsulation
# Difficulty: Beginner
# Importance of Encapsulation in Python: Provides data protection
# ---------------
# Concept: Inheritance
# Difficulty: Advanced
# Advantages of Inheritance in Python: Code reusability and extensibility
# ---------------
